# %%
import pandas as pd


try:
    url_alumnos = "https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv"
    url_casas = "https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv"
    data_casas = 'C:/Users/wmalv/OneDrive/Escritorio/DATA/Alura---DataScience/Pandas/alquiler.csv'
    df = pd.read_csv(url_casas, sep=';')
    df.head(10)
except FileNotFoundError:
    print("El archivo no se encuentra en la ruta especificada.")
except pd.errors.EmptyDataError:
    print("El archivo está vacío.")
except Exception as e:
    print(f"Se produjo un error: {e}")

# %%
df.sample(10)
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 19673             Departamento              Santa Fe             3        2
# 11338  Conjunto Comercial/Sala      Centro Histórico             0        0
# 17068  Conjunto Comercial/Sala              Santa Fe             0        0
# 10423  Conjunto Comercial/Sala               Condesa             0        0
# 2781              Departamento  Bosques de las Lomas             2        1
# 16428             Tienda/Salón               Condesa             0        1
# 20312             Departamento              Narvarte             2        1
# 18165             Departamento              Coyoacán             3        1
# 1944   Conjunto Comercial/Sala      Centro Histórico             0        0
# 10636             Departamento               Condesa             3        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 19673       1   100   8750.0      5320.0    1225.0
# ...

# %%
df.describe()
# Out:
#        Habitaciones       Garages        Suites          Area         Valor  \
# count  25121.000000  25121.000000  25121.000000  25121.000000  2.510700e+04
# mean       1.748856      1.798655      0.656781    220.885076  3.688505e+04
# std        1.811131     22.906129      1.083180    817.465428  3.669381e+05
# min        0.000000      0.000000      0.000000      0.000000  3.150000e+02
# 25%        0.000000      0.000000      0.000000     55.000000  5.600000e+03
# 50%        2.000000      1.000000      0.000000     90.000000  1.137500e+04
# 75%        3.000000      2.000000      1.000000    180.000000  2.695000e+04
# max      100.000000   1966.000000     24.000000  42000.000000  5.250000e+07
#
#          Condominio      Impuesto
# count  2.249500e+04  1.803700e+04
# mean   9.528676e+03  4.436513e+03
# std    1.547102e+05  2.283381e+04
# min    3.500000e+00  3.500000e+00
# 25%    2.275000e+03  4.270000e+02
# 50%    4.056500e+03  1.008000e+03
# 75%    7.350000e+03  2.625000e+03
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Exploracion

# %%
df.shape
# Out:
# (25121, 9)

# %%
df.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
df['Tipo'].value_counts()
# Out:
# Tipo
# Departamento                  14764
# Conjunto Comercial/Sala        5681
# Tienda/Salón                   1098
# Cocineta                        726
# Casa de Condominio              610
# Casa                            545
# Departamento en Hotel           455
# Galpón/Depósito/Almacén         289
# Edificio Completo               217
# Casa Comercial                  202
# Tienda en Centro Comercial      197
# Casa de Vecindad                158
# Cochera/Estacionamiento          77
# Terreno Estándar                 45
# Loft                             38
# Rancho                            8
# Estudio                           4
# Loteo/Condominio                  3
# Hotel                             2
# Posada/Chalé                      1
# Industria                         1
# Name: count, dtype: int64

# %%
df[['Habitaciones','Valor']].sum()
# Out:
# Habitaciones        43933.0
# Valor           926072962.5
# dtype: float64

# %%
df_alumnos = pd.read_csv(url_alumnos)
df_alumnos.head()
# Out:
#     Nombre  Edad  Nota Aprobado
# 0  Alberto    20   7.5     True
# 1      Ana    18   NaN    False
# 2   Camila    27   2.5    False
# 3    David    18   5.0    False
# 4    Brian    21  10.0     True

# %%
df_alumnos.describe()
# Out:
#             Edad       Nota
# count  18.000000  12.000000
# mean   25.500000   6.841667
# std     6.070662   2.264532
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %% [markdown]
# ## Demandas ML

# %% [markdown]
# Algunas preguntas que podemos hacer en este momento son:
#
# ¿Cuáles son los valores promedio de alquiler por tipo de propiedad?

# %%
df.sample(10)
# Out:
#                           Tipo                 Colonia  Habitaciones  Garages  \
# 18868             Departamento                Santa Fe             2        1
# 22752             Departamento                    Roma             2        1
# 14811             Departamento                Coyoacán             1        0
# 45                Departamento                Coyoacán             3        2
# 19103             Departamento               Del Valle             3        1
# 2320   Conjunto Comercial/Sala                Santa Fe             0        1
# 650               Departamento                Coyoacán             3        0
# 9                     Cocineta                 Condesa             1        0
# 7212   Conjunto Comercial/Sala                Santa Fe             0        2
# 1884              Departamento  San Miguel Chapultepec             2        1
#
#        Suites  Area    Valor  Condominio  Impuesto
# 18868       1    74   6650.0      4165.0     752.5
# ...

# %%
df.describe()
# Out:
#        Habitaciones       Garages        Suites          Area         Valor  \
# count  25121.000000  25121.000000  25121.000000  25121.000000  2.510700e+04
# mean       1.748856      1.798655      0.656781    220.885076  3.688505e+04
# std        1.811131     22.906129      1.083180    817.465428  3.669381e+05
# min        0.000000      0.000000      0.000000      0.000000  3.150000e+02
# 25%        0.000000      0.000000      0.000000     55.000000  5.600000e+03
# 50%        2.000000      1.000000      0.000000     90.000000  1.137500e+04
# 75%        3.000000      2.000000      1.000000    180.000000  2.695000e+04
# max      100.000000   1966.000000     24.000000  42000.000000  5.250000e+07
#
#          Condominio      Impuesto
# count  2.249500e+04  1.803700e+04
# mean   9.528676e+03  4.436513e+03
# std    1.547102e+05  2.283381e+04
# min    3.500000e+00  3.500000e+00
# 25%    2.275000e+03  4.270000e+02
# 50%    4.056500e+03  1.008000e+03
# 75%    7.350000e+03  2.625000e+03
# ...

# %%
df['Valor'].mean()
# Out:
# np.float64(36885.05048392878)

# %%
df['Tipo'].value_counts()
# Out:
# Tipo
# Departamento                  14764
# Conjunto Comercial/Sala        5681
# Tienda/Salón                   1098
# Cocineta                        726
# Casa de Condominio              610
# Casa                            545
# Departamento en Hotel           455
# Galpón/Depósito/Almacén         289
# Edificio Completo               217
# Casa Comercial                  202
# Tienda en Centro Comercial      197
# Casa de Vecindad                158
# Cochera/Estacionamiento          77
# Terreno Estándar                 45
# Loft                             38
# Rancho                            8
# Estudio                           4
# Loteo/Condominio                  3
# Hotel                             2
# Posada/Chalé                      1
# Industria                         1
# Name: count, dtype: int64

# %%
df.groupby('Tipo').mean(numeric_only=True)
# Out:
#                             Habitaciones    Garages     Suites          Area  \
# Tipo
# Casa                            3.359633   1.897248   1.438532    289.943119
# Casa Comercial                  1.801980   2.118812   0.257426    370.277228
# Casa de Condominio              4.319672   3.555738   3.247541    566.303279
# Casa de Vecindad                1.974684   0.379747   0.215190     79.981013
# Cochera/Estacionamiento         0.064935   1.376623   0.000000     18.662338
# Cocineta                        0.836088   0.020661   0.041322     29.090909
# Conjunto Comercial/Sala         0.047175   2.686323   0.000352    236.323711
# Departamento                    2.504199   1.256367   0.891899    124.014292
# Departamento en Hotel           1.419780   0.969231   0.758242     65.848352
# Edificio Completo               0.405530  11.175115   0.027650   1717.271889
# Estudio                         0.500000   0.250000   0.000000    103.250000
# ...

# %%
df.groupby('Tipo').aggregate(Valor=('Valor', 'mean'))     # Creo una columna con el mean llamado Valor
# Out:
#                                     Valor
# Tipo
# Casa                         31453.177064
# Casa Comercial               54735.841584
# Casa de Condominio           51428.609836
# Casa de Vecindad              5961.740506
# Cochera/Estacionamiento       6995.454545
# Cocineta                      4425.856061
# Conjunto Comercial/Sala      57675.214550
# Departamento                 18683.269431
# Departamento en Hotel        16285.430769
# Edificio Completo           409418.080645
# Estudio                       8400.000000
# Galpón/Depósito/Almacén     299984.140138
# Hotel                        87500.000000
# Industria                   420000.000000
# Loft                          9924.526316
# Loteo/Condominio             92166.666667
# Posada/Chalé                  5180.000000
# Rancho                       38014.375000
# Terreno Estándar            135364.444444
# Tienda en Centro Comercial   32556.785714
# Tienda/Salón                 56263.544252

# %%
df.groupby('Tipo')['Valor'].mean()          # No creo una columna, la uso para que me muestre el resultado.
# Out:
# Tipo
# Casa                           31453.177064
# Casa Comercial                 54735.841584
# Casa de Condominio             51428.609836
# Casa de Vecindad                5961.740506
# Cochera/Estacionamiento         6995.454545
# Cocineta                        4425.856061
# Conjunto Comercial/Sala        57675.214550
# Departamento                   18683.269431
# Departamento en Hotel          16285.430769
# Edificio Completo             409418.080645
# Estudio                         8400.000000
# Galpón/Depósito/Almacén       299984.140138
# Hotel                          87500.000000
# Industria                     420000.000000
# Loft                            9924.526316
# Loteo/Condominio               92166.666667
# Posada/Chalé                    5180.000000
# Rancho                         38014.375000
# Terreno Estándar              135364.444444
# Tienda en Centro Comercial     32556.785714
# Tienda/Salón                   56263.544252
# ...

# %%
df.groupby('Tipo')[['Valor']].mean().sort_values('Valor', ascending=False)
# Out:
#                                     Valor
# Tipo
# Industria                   420000.000000
# Edificio Completo           409418.080645
# Galpón/Depósito/Almacén     299984.140138
# Terreno Estándar            135364.444444
# Loteo/Condominio             92166.666667
# Hotel                        87500.000000
# Conjunto Comercial/Sala      57675.214550
# Tienda/Salón                 56263.544252
# Casa Comercial               54735.841584
# Casa de Condominio           51428.609836
# Rancho                       38014.375000
# Tienda en Centro Comercial   32556.785714
# Casa                         31453.177064
# Departamento                 18683.269431
# Departamento en Hotel        16285.430769
# Loft                          9924.526316
# Estudio                       8400.000000
# Cochera/Estacionamiento       6995.454545
# Casa de Vecindad              5961.740506
# Posada/Chalé                  5180.000000
# Cocineta                      4425.856061

# %%
means_type_value = df.groupby('Tipo')[['Valor']].mean().sort_values('Valor', ascending=True)
means_type_value.plot(kind='barh', figsize=(10, 6), color='green')
# Out:
# <Axes: ylabel='Tipo'>

# %%
import pandas as pd

df_test_01 = pd.DataFrame({
   'Animal': ['Perro', 'Gato', 'Elefante', 'Perro', 'Gato', 'Elefante'],
   'Color': ['Negro', 'Blanco', 'Gris', 'Marrón', 'Negro', 'Marrón'],
   'Cantidad': [2, 3, 1, 4, 2, 2]
})
df_test_01
# Out:
#      Animal   Color  Cantidad
# 0     Perro   Negro         2
# 1      Gato  Blanco         3
# 2  Elefante    Gris         1
# 3     Perro  Marrón         4
# 4      Gato   Negro         2
# 5  Elefante  Marrón         2

# %%
df_test_01.groupby('Animal').sum()
# Out:
#                 Color  Cantidad
# Animal
# Elefante   GrisMarrón         3
# Gato      BlancoNegro         5
# Perro     NegroMarrón         6

# %%
df_test_01.groupby(['Animal', 'Color']).sum()
# Out:
#                  Cantidad
# Animal   Color
# Elefante Gris           1
#          Marrón         2
# Gato     Blanco         3
#          Negro          2
# Perro    Marrón         4
#          Negro          2

# %%
df_test_01.groupby(['Animal', 'Color']).sum().unstack()
# Out:
#          Cantidad
# Color      Blanco Gris Marrón Negro
# Animal
# Elefante      NaN  1.0    2.0   NaN
# Gato          3.0  NaN    NaN   2.0
# Perro         NaN  NaN    4.0   2.0

# %%
df.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Conjunto Comercial/Sala', 'Departamento',
#        'Casa de Condominio', 'Edificio Completo', 'Departamento en Hotel',
#        'Tienda/Salón', 'Casa Comercial', 'Casa de Vecindad',
#        'Terreno Estándar', 'Cochera/Estacionamiento', 'Loft',
#        'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Rancho',
#        'Posada/Chalé', 'Estudio', 'Hotel', 'Loteo/Condominio',
#        'Industria'], dtype=object)

# %%
data_comerciales = ['Conjunto Comercial/Sala', 'Edificio Completo', 'Tienda/Salón', 'Casa Comercial',
       'Terreno Estándar', 'Cochera/Estacionamiento', 'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial',
       'Hotel', 'Loteo/Condominio', 'Industria']

# %%
df.query("@data_comerciales in Tipo")
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 2      Conjunto Comercial/Sala          Santa Fe             0        4
# 6      Conjunto Comercial/Sala  Centro Histórico             0        3
# 11           Edificio Completo              Roma             0        0
# 24     Conjunto Comercial/Sala          Santa Fe             0        1
# 26     Conjunto Comercial/Sala  Centro Histórico             0        5
# ...                        ...               ...           ...      ...
# 25107  Conjunto Comercial/Sala          Santa Fe             0        1
# 25110  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25112  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25116  Cochera/Estacionamiento  Centro Histórico             0        0
# 25120  Conjunto Comercial/Sala  Centro Histórico             0        0
#
#        Suites  Area     Valor  Condominio  Impuesto
# ...

# %%
df.query("@data_comerciales not in Tipo")
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# ...

# %%
df_residenciales = df.query("@data_comerciales not in Tipo")
df_residenciales
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# ...

# %%
df_residenciales.groupby('Tipo').aggregate(Valor=('Valor', 'mean')).sort_values('Valor', ascending=False)
# Out:
#                               Valor
# Tipo
# Casa de Condominio     51428.609836
# Rancho                 38014.375000
# Casa                   31453.177064
# Departamento           18683.269431
# Departamento en Hotel  16285.430769
# Loft                    9924.526316
# Estudio                 8400.000000
# Casa de Vecindad        5961.740506
# Posada/Chalé            5180.000000
# Cocineta                4425.856061

# %%
rmeans_type_value = df_residenciales.groupby('Tipo').aggregate(Valor=('Valor', 'mean')).sort_values('Valor', ascending=False)
rmeans_type_value.plot(kind='barh', figsize=(10, 6), color='purple')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# ¿Cuál es el porcentaje de cada tipo de propiedad en nuestra base de datos?"

# %%
df_residenciales.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Departamento', 'Casa de Condominio',
#        'Departamento en Hotel', 'Casa de Vecindad', 'Loft', 'Rancho',
#        'Posada/Chalé', 'Estudio'], dtype=object)

# %%
df_residenciales.Tipo.value_counts()
# Out:
# Tipo
# Departamento             14764
# Cocineta                   726
# Casa de Condominio         610
# Casa                       545
# Departamento en Hotel      455
# Casa de Vecindad           158
# Loft                        38
# Rancho                       8
# Estudio                      4
# Posada/Chalé                 1
# Name: count, dtype: int64

# %%
df_residenciales.Tipo.value_counts(normalize=True)
# Out:
# Tipo
# Departamento             0.852967
# Cocineta                 0.041943
# Casa de Condominio       0.035242
# Casa                     0.031487
# Departamento en Hotel    0.026287
# Casa de Vecindad         0.009128
# Loft                     0.002195
# Rancho                   0.000462
# Estudio                  0.000231
# Posada/Chalé             0.000058
# Name: proportion, dtype: float64

# %%
df_residenciales.query('Tipo == "Departamento"').sample(5)
# Out:
#                Tipo   Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 7689   Departamento  Coyoacán             4        2       1   210  56000.0
# 12512  Departamento  Coyoacán             3        1       1   112  27300.0
# 22551  Departamento  Coyoacán             3        2       2   170  34650.0
# 21455  Departamento  Santa Fe             2        1       1    94   8750.0
# 5395   Departamento   Polanco             2        0       0    68  10150.0
#
#        Condominio  Impuesto
# 7689      11200.0    2800.0
# 12512      5250.0       NaN
# 22551     15050.0       NaN
# 21455      6300.0      94.5
# 5395       1155.0     283.5

# %%
average_type = df_residenciales.Tipo.value_counts(normalize=True).to_frame()
average_type.plot(kind='bar', figsize=(10, 6), color='green', xlabel='Tipo', ylabel='Porcentaje')
# Out:
# <Axes: xlabel='Tipo', ylabel='Porcentaje'>

# %%
df_residenciales.groupby('Tipo')['Habitaciones'].mean()
# Out:
# Tipo
# Casa                      3.359633
# Casa de Condominio        4.319672
# Casa de Vecindad          1.974684
# Cocineta                  0.836088
# Departamento              2.504199
# Departamento en Hotel     1.419780
# Estudio                   0.500000
# Loft                      1.078947
# Posada/Chalé             23.000000
# Rancho                    5.125000
# Name: Habitaciones, dtype: float64

# %%
df.shape
# Out:
# (25121, 9)

# %%
df.isnull().sum()
# Out:
# Tipo               0
# Colonia            0
# Habitaciones       0
# Garages            0
# Suites             0
# Area               0
# Valor             14
# Condominio      2626
# Impuesto        7084
# dtype: int64

# %%
df_residenciales.shape
# Out:
# (17309, 9)

# %%
df_residenciales.isnull().sum()
# Out:
# Tipo               0
# Colonia            0
# Habitaciones       0
# Garages            0
# Suites             0
# Area               0
# Valor              7
# Condominio      1155
# Impuesto        4645
# dtype: int64

# %% [markdown]
# #### Fillna -- Rellenar datos nulos with 0

# %%
df_residenciales = df_residenciales.fillna(0)
df_residenciales.isnull().sum()
# Out:
# Tipo            0
# Colonia         0
# Habitaciones    0
# Garages         0
# Suites          0
# Area            0
# Valor           0
# Condominio      0
# Impuesto        0
# dtype: int64

# %% [markdown]
# #### Remove data with errors

# %%
## Remover departamentos con valor igual a 0
df_residenciales.query('Valor == 0').shape
# Out:
# (0, 9)

# %%
df_residenciales.query('Condominio == 0').shape
# Out:
# (0, 9)

# %%
df_residenciales.query('Valor == 0 | Condominio == 0').shape         #### Mostrar departamentos con Valor o Condominio igual a 0
# Out:
# (0, 9)

# %%
df_residenciales.query('Valor == 0 | Condominio == 0').index        #### Mostrar indices de los departamentos con Valor o Condominio igual a 0
# Out:
# Index([], dtype='int64')

# %%
df_residenciales_filter = df_residenciales.query('Valor == 0 | Condominio == 0').index

# %%
df_residenciales.drop(df_residenciales_filter, axis=0 ,inplace=True)        ## Eliminar departamentos con Valor o Condominio igual a 0. 
## axis = 0 filas, axis = 1 columnas, inplace = True para guardar los cambios

# %%
df_residenciales.query('Valor == 0 | Condominio == 0').index
# Out:
# Index([], dtype='int64')

# %%
df_residenciales.head(10)
# Out:
#                      Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                Cocineta           Condesa             1        0       0
# 3            Departamento  Centro Histórico             1        0       0
# 4            Departamento         Del Valle             1        0       0
# 8            Departamento           Condesa             1        0       1
# 9                Cocineta           Condesa             1        0       0
# 10           Departamento           Condesa             4        3       1
# 12  Departamento en Hotel              Roma             3        1       1
# 13           Departamento          Santa Fe             2        1       1
# 14           Departamento          Narvarte             2        1       0
# 15     Casa de Condominio          Santa Fe             4        3       2
#
#     Area    Valor  Condominio  Impuesto
# 0     40   5950.0      1750.0     210.0
# 3     15   2800.0      1365.0      70.0
# ...

# %%
df_residenciales.Tipo.unique()
# Out:
# array(['Cocineta', 'Departamento', 'Departamento en Hotel',
#        'Casa de Condominio', 'Casa', 'Loft', 'Casa de Vecindad',
#        'Posada/Chalé', 'Estudio'], dtype=object)

# %%
datos_mercado = pd.DataFrame([['Plaza', 'Cebolla', 2.5], 
                      ['Mercado', 'Cebolla', 1.99], 
                      ['Supermercado', 'Cebolla', 1.69], 
                      ['Plaza', 'Tomate', 4], 
                      ['Mercado', 'Tomate', 3.29], 
                      ['Supermercado', 'Tomate', 2.99], 
                      ['Plaza', 'Papa', 4.2], 
                      ['Mercado', 'Papa', 3.99], 
                      ['Supermercado', 'Papa', 3.69]],
                      columns = ['Comercio', 'Producto', 'Precio'])

# %%
datos_mercado.head(10)
# Out:
#        Comercio Producto  Precio
# 0         Plaza  Cebolla    2.50
# 1       Mercado  Cebolla    1.99
# 2  Supermercado  Cebolla    1.69
# 3         Plaza   Tomate    4.00
# 4       Mercado   Tomate    3.29
# 5  Supermercado   Tomate    2.99
# 6         Plaza     Papa    4.20
# 7       Mercado     Papa    3.99
# 8  Supermercado     Papa    3.69

# %%
datos_mercado.drop([2, 5, 8], axis=0, inplace=True)

# %%
datos_mercado.groupby(['Comercio', 'Producto'])[['Precio']].sum()
# Out:
#                    Precio
# Comercio Producto
# Mercado  Cebolla     1.99
#          Papa        3.99
#          Tomate      3.29
# Plaza    Cebolla     2.50
#          Papa        4.20
#          Tomate      4.00

# %% [markdown]
# 1. Apartamentos que tienen 1 dormitorio y un alquiler menor a MXN 4200.
#
# 2. Apartamentos que tienen al menos 2 dormitorios, un alquiler menor a MXN 10500 y una superficie mayor a 70 m².

# %%
df_residenciales['Tipo'].value_counts()
# Out:
# Tipo
# Departamento             14264
# Cocineta                   681
# Casa de Condominio         552
# Departamento en Hotel      415
# Casa                       134
# Casa de Vecindad            63
# Loft                        35
# Estudio                      2
# Posada/Chalé                 1
# Name: count, dtype: int64

# %%
df_departamentos = df_residenciales[df_residenciales['Tipo'] == 'Departamento']
df_departamentos.head(10)
# Out:
#             Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3   Departamento  Centro Histórico             1        0       0    15
# 4   Departamento         Del Valle             1        0       0    48
# 8   Departamento           Condesa             1        0       1    40
# 10  Departamento           Condesa             4        3       1   243
# 13  Departamento          Santa Fe             2        1       1    67
# 14  Departamento          Narvarte             2        1       0   110
# 16  Departamento          Narvarte             2        1       0    78
# 18  Departamento          Coyoacán             3        1       1   125
# 19  Departamento          Narvarte             1        0       0    48
# 20  Departamento          Santa Fe             3        3       1   175
#
#       Valor  Condominio  Impuesto
# 3    2800.0      1365.0      70.0
# 4    2800.0       805.0       0.0
# 8    7000.0      1963.5     175.0
# 10  45500.0      7000.0    2810.5
# ...

# %%
df_departamentos[df_departamentos['Habitaciones'] == 1]
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 8      Departamento               Condesa             1        0       1
# 19     Departamento              Narvarte             1        0       0
# 37     Departamento      Centro Histórico             1        0       0
# ...             ...                   ...           ...      ...     ...
# 25090  Departamento              Coyoacán             1        0       0
# 25092  Departamento              Santa Fe             1        1       0
# 25100  Departamento  Lomas de Chapultepec             1        1       1
# 25103  Departamento               Condesa             1        0       0
# 25114  Departamento              Narvarte             1        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
df_d_filter_01 = df_departamentos['Habitaciones'] == 1
df_d_filter_02 = df_departamentos['Valor'] <= 4200

# %%
df_departamentos[df_d_filter_01 & df_d_filter_02]
# Out:
#                Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3      Departamento  Centro Histórico             1        0       0    15
# 4      Departamento         Del Valle             1        0       0    48
# 19     Departamento          Narvarte             1        0       0    48
# 37     Departamento  Centro Histórico             1        0       0    27
# 61     Departamento  Centro Histórico             1        1       0    37
# ...             ...               ...           ...      ...     ...   ...
# 24710  Departamento         Nativitas             1        0       0    40
# 24872  Departamento        Peralvillo             1        0       1    69
# 24880  Departamento        La Condesa             1        0       0    46
# 24943  Departamento              Roma             1        0       0    21
# 25114  Departamento          Narvarte             1        0       0    28
#
#         Valor  Condominio  Impuesto
# ...

# %%
df_departamentos[df_d_filter_01 & df_d_filter_02].max()
# Out:
# Tipo              Departamento
# Colonia         Álvaro Obregón
# Habitaciones                 1
# Garages                      2
# Suites                       1
# Area                        99
# Valor                   4200.0
# Condominio              9275.0
# Impuesto                3150.0
# dtype: object

# %%
df_d_filter_03= (df_departamentos['Habitaciones'] >= 1) & (df_departamentos['Valor'] <= 10500) & (df_departamentos['Area'] >= 70)

# %%
df_departamentos[df_d_filter_03]
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 14     Departamento              Narvarte             2        1       0
# 16     Departamento              Narvarte             2        1       0
# 21     Departamento                  Roma             2        1       0
# 28     Departamento              Santa Fe             3        1       2
# 33     Departamento              Santa Fe             3        1       1
# ...             ...                   ...           ...      ...     ...
# 25063  Departamento              Narvarte             3        1       0
# 25105  Departamento              Santa Fe             2        1       1
# 25106  Departamento              Santa Fe             3        2       0
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 14      110   6650.0      2450.0     483.0
# ...

# %%
df_departamentos_f1 = df_departamentos[df_d_filter_01 & df_d_filter_02]
df_departamentos_f2 = df_departamentos[df_d_filter_03]

# %%
df_departamentos_f1.shape
# Out:
# (471, 9)

# %%
df_departamentos_f2.shape
# Out:
# (3592, 9)

# %% [markdown]
# Para finalizar, necesitamos almacenar nuestros dataframes en formato csv, tras realizar todos los análisis y tratamientos.

# %%
df_departamentos_f1.to_csv('df_departamentos_f1.csv', index=False, sep=';')          ## Normalmente se lleva el anterior indice. Por eso se usa index False, para que no lo lleve.
df_departamentos_f2.to_csv('df_departamentos_f2.csv', index=False, sep=';')

# %% [markdown]
# ## Demandas DEV

# %% [markdown]
# 1. valor_mensual: Esta columna debe contener los gastos mensuales de cada propiedad, incluyendo el alquiler y el condominio.
# 2. valor_anual: Esta columna debe contener los gastos anuales por propiedad, es decir, el Impuesto más 12 meses de alquiler y condominio.

# %%
df.shape
# Out:
# (25121, 9)

# %%
df.sample(10)    ## frac=0.25 es el 25%
# Out:
#                           Tipo                 Colonia  Habitaciones  Garages  \
# 17910             Departamento                Coyoacán             3        2
# 19476             Departamento                Santa Fe             4        2
# 15132             Tienda/Salón        Centro Histórico             0        0
# 15079       Casa de Condominio                Santa Fe             4        5
# 18845             Departamento                 Condesa             3        1
# 12353             Departamento  San Miguel Chapultepec             2        1
# 21342             Departamento                Coyoacán             3        1
# 5873   Conjunto Comercial/Sala         Villa de Cortés             0       10
# 10304             Departamento                Santa Fe             2        1
# 5447              Departamento                Santa Fe             3        3
#
#        Suites  Area     Valor  Condominio  Impuesto
# 17910       1   150   22050.0      7700.0    1732.5
# ...

# %%
df['Valor Mensual'] = df['Valor'] + df['Condominio']
df.sample(10)
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 8650              Departamento  Bosques de las Lomas             4        4
# 18121             Departamento  Lomas de Chapultepec             3        1
# 4919              Departamento              Santa Fe             2        1
# 5470              Departamento            San Rafael             1        0
# 18003             Departamento               Condesa             3        0
# 6163   Conjunto Comercial/Sala              Coyoacán             0        0
# 4921   Conjunto Comercial/Sala              Santa Fe             0        1
# 14729  Conjunto Comercial/Sala      Centro Histórico             0        0
# 6555   Conjunto Comercial/Sala    Villa de Guadalupe             0        1
# 4486              Departamento                  Roma             2        1
#
#        Suites  Area    Valor  Condominio  Impuesto  Valor Mensual
# 8650        4   400  70000.0     14700.0   52500.0        84700.0
# ...

# %%
df['Valor Anual']  = df['Valor Mensual'] * 12 + df['Impuesto']
df.tail(10)
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25111             Departamento  Lomas de Chapultepec             3        0
# 25112  Conjunto Comercial/Sala      Centro Histórico             0        0
# 25113             Departamento              Coyoacán             3        1
# 25114             Departamento              Narvarte             1        0
# 25115       Casa de Condominio              Santa Fe             5        3
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto  Valor Mensual  Valor Anual
# ...

# %% [markdown]
# 1. Descripcion: Esta columna debe contener un resumen de la información clave de las propiedades que se mostrarán en el sitio web: tipo de propiedad, barrio, cantidad de habitaciones y plazas de estacionamiento.

# %%
df['Descripcion'] = df['Tipo'] + ', Colonia: ' + df['Colonia'] + ', Habitaciones: '\
                    + df['Habitaciones'].astype(str)    ## se usaa el astype para que lo convierta en string y poderlo concatenar con el resto
df['Descripcion'].tail(10)
# Out:
# 25111    Departamento, Colonia: Lomas de Chapultepec, H...
# 25112    Conjunto Comercial/Sala, Colonia: Centro Histó...
# 25113     Departamento, Colonia: Coyoacán, Habitaciones: 3
# 25114     Departamento, Colonia: Narvarte, Habitaciones: 1
# 25115    Casa de Condominio, Colonia: Santa Fe, Habitac...
# 25116    Cochera/Estacionamiento, Colonia: Centro Histó...
# 25117    Cocineta, Colonia: Centro Histórico, Habitacio...
# 25118      Departamento, Colonia: Mixcoac, Habitaciones: 2
# 25119    Departamento, Colonia: Lomas de Chapultepec, H...
# 25120    Conjunto Comercial/Sala, Colonia: Centro Histó...
# Name: Descripcion, dtype: object

# %% [markdown]
# 2. Tiene_suite: Esta debe ser una columna que indique únicamente si la propiedad tiene o no suites, sin importar la cantidad.

# %%
df['Tiene Suits'] = df['Suites'].apply(lambda x: 'Si' if x > 0 else 'No')
df[['Suites', 'Tiene Suits']].sample(10)
# Out:
#        Suites Tiene Suits
# 14859       2          Si
# 8343        2          Si
# 1011        0          No
# 21545       0          No
# 22615       0          No
# 22201       0          No
# 6778        0          No
# 313         0          No
# 17767       0          No
# 14999       1          Si

# %%
df.to_csv('df.csv', index=False, sep=';')

# %% [markdown]
# Para practicar los métodos aprendidos a lo largo de esta lección y aprender nuevos, realizaremos algunos tratamientos y selecciones utilizando un archivo CSV diferente: alumnos.csv.
#
# Este archivo es el mismo que se utilizó para resolver los desafíos de la lección 1 y contiene datos de estudiantes de un curso superior.
#
# Basándonos en esto, resolvamos los problemas propuestos a continuación utilizando los conocimientos adquiridos hasta ahora.
#
# Verifica si la base de datos contiene datos nulos y, en caso de tenerlos, realiza el tratamiento de estos datos nulos de la manera que consideres más coherente con la situación.
#
# Los estudiantes "Alicia" y "Carlos" ya no forman parte del grupo. Por lo tanto, elimínalos de la base de datos.
#
# Aplica un filtro que seleccione solo a los estudiantes que fueron aprobados.
#
# Guarda el DataFrame que contiene solo a los estudiantes aprobados en un archivo CSV llamado "alumnos_aprobados.csv".
#
# Extra: Al revisar las calificaciones de los estudiantes aprobados, notamos que algunas calificaciones eran incorrectas. Las estudiantes que obtuvieron una calificación de 7.0, en realidad tenían un punto extra que no se contabilizó. Por lo tanto, reemplaza las calificaciones de 7.0 en la base de datos por 8.0. Consejo: busca el método replace.
#
# Si necesitas ayuda, en la sección "Opinión del Instructor" puedes encontrar algunas formas de resolver los desafíos propuestos anteriormente.

# %% [markdown]
# Este archivo es el mismo que se utilizó para resolver los desafíos de las aulas 1 y 3 y contiene datos de estudiantes de un curso superior. Con base en esto, resolvamos los problemas propuestos a continuación utilizando los conocimientos adquiridos hasta ahora.
#
# Los estudiantes participaron en una actividad extracurricular y ganaron puntos extras. Estos puntos extras corresponden al 40% de su nota actual. Por lo tanto, crea una columna llamada "Puntos_extras" que contenga los puntos extras de cada estudiante, es decir, el 40% de su nota actual.
#
# Crea otra columna llamada "Notas_finales" que contenga las notas de cada estudiante sumadas con los puntos extras.
#
# Dado que hubo una puntuación extra, algunos estudiantes que no habían sido aprobados antes pueden haber sido aprobados ahora. En función de esto, crea una columna llamada "Aprobado_final" con los siguientes valores:
#
# True: si el estudiante está aprobado (la nota final debe ser mayor o igual a 7.0).
# False: si el estudiante está reprobado (la nota final debe ser menor que 7.0).
# Realiza una selección y verifica qué estudiantes no habían sido aprobados anteriormente, pero ahora fueron aprobados después de sumar los puntos extras.
#
# Si necesitas ayuda, en la sección "Opinión del Instructor", puedes encontrar algunas formas de resolver los desafíos propuestos anteriormente.
